# %% [markdown]
# # **Proyecto final IA**
# **Autor:** Jhon Edinson Salazar Lemus
# **Grupo:** G1

# %% [markdown]
# # **Primera entrega**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1 -Shape, columns and head

# %%
dataFrame = pd.read_csv("sample_data/test.csv", sep=",", encoding="latin1")
dataFrame = dataFrame.replace({r'[^\x00-\x7F]+':''}, regex=True)
print("Shape: ", dataFrame.shape)
print("Columns: ", dataFrame.columns)
dataFrame.head(10)
# Out:
# Shape:  (14900, 24)
# Columns:  Index(['Employee ID', 'Age', 'Gender', 'Years at Company', 'Job Role',
#        'Monthly Income', 'Work-Life Balance', 'Job Satisfaction',
#        'Performance Rating', 'Number of Promotions', 'Overtime',
#        'Distance from Home', 'Education Level', 'Marital Status',
#        'Number of Dependents', 'Job Level', 'Company Size', 'Company Tenure',
#        'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities',
#        'Company Reputation', 'Employee Recognition', 'Attrition'],
#       dtype='object')
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0        52685   36    Male                13  Healthcare            8029
# 1        30585   35    Male                 7   Education            4563
# 2        54656   50    Male                 7   Education            5583
# 3        33442   58    Male                44       Media            5525
# ...

# %% [markdown]
# ## 2 - Dataset Describe

# %%
dataFrame.describe()
# Out:
#         Employee ID           Age  Years at Company  Monthly Income  \
# count  14900.000000  14900.000000      14900.000000    14900.000000
# mean   37339.022081     38.385235         15.592416     7287.306040
# std    21453.129293     12.097904         11.133792     2156.737934
# min        5.000000     18.000000          1.000000     1226.000000
# 25%    18825.500000     28.000000          7.000000     5633.750000
# 50%    37433.000000     38.000000         13.000000     7332.000000
# 75%    55857.500000     49.000000         23.000000     8852.000000
# max    74471.000000     59.000000         51.000000    15063.000000
#
#        Number of Promotions  Distance from Home  Number of Dependents  \
# count          14900.000000        14900.000000          14900.000000
# mean               0.834362           49.927315              1.659329
# std                0.996511           28.702307              1.545401
# min                0.000000            1.000000              0.000000
# ...

# %% [markdown]
# ## 3 - Limpieza del dataset
#
# Del conjunto de columnas encontradas en el data set, cada una de ellas contenia informacion significante que podia indicar algun factor determinante al momento de decidir si el empleado se queda o no en la empresa, al final se encontro que solo una columna era dispensable del data set y era la de
#
# - **Employee ID**: Id del empleado dentro de la empresa

# %%
dataFrame = dataFrame.drop('Employee ID', axis=1)

# %% [markdown]
# ## 4 - Graficas de las columnas

# %%
fig, axes = plt.subplots(4, 2, figsize=(12, 12))

dataFrame.hist('Age', ax=axes[0, 0])
dataFrame.hist('Years at Company', ax=axes[0, 1])
dataFrame.hist('Monthly Income', ax=axes[1, 0])
dataFrame.hist('Number of Promotions', ax=axes[1, 1])
dataFrame.hist('Distance from Home', ax=axes[2, 0])
dataFrame.hist('Number of Dependents', ax=axes[2, 1])
dataFrame.hist('Company Tenure', ax=axes[3, 0])

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(8, 2, figsize=(30, 30))

counts = dataFrame['Employee Recognition'].value_counts()
axes[0, 0].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[0, 0].set_title("Employee Recognition")

counts = dataFrame['Gender'].value_counts()
axes[0, 1].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[0, 1].set_title("Gender")

counts = dataFrame['Job Role'].value_counts()
axes[1, 0].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[1, 0].set_title("Job Role")

counts = dataFrame['Attrition'].value_counts()
axes[1, 1].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[1, 1].set_title("Attrition")

counts = dataFrame['Work-Life Balance'].value_counts()
axes[2, 0].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[2, 0].set_title("Work-Life Balance")

counts = dataFrame['Job Satisfaction'].value_counts()
axes[2, 1].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[2, 1].set_title("Job Satisfaction")

counts = dataFrame['Performance Rating'].value_counts()
axes[3, 0].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[3, 0].set_title("Performance Rating")

counts = dataFrame['Overtime'].value_counts()
axes[3, 1].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[3, 1].set_title("Overtime")

counts = dataFrame['Education Level'].value_counts()
axes[4, 0].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[4, 0].set_title("Education Level")

counts = dataFrame['Marital Status'].value_counts()
axes[4, 1].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[4, 1].set_title("Marital Status")

counts = dataFrame['Job Level'].value_counts()
axes[5, 0].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[5, 0].set_title("Job Level")

counts = dataFrame['Company Size'].value_counts()
axes[5, 1].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[5, 1].set_title("Company Size")

counts = dataFrame['Remote Work'].value_counts()
axes[6, 0].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[6, 0].set_title("Remote Work")

counts = dataFrame['Leadership Opportunities'].value_counts()
axes[6, 1].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[6, 1].set_title("Leadership Opportunities")

counts = dataFrame['Innovation Opportunities'].value_counts()
axes[7, 0].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[7, 0].set_title("Innovation Opportunities")

counts = dataFrame['Company Reputation'].value_counts()
axes[7, 1].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
axes[7, 1].set_title("Company Reputation")

plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# ## 5 - Clasificacion o Regresion
#
# El proyecto se enmarca dentro de un problema de aprendizaje supervisado de clasificación. La variable objetivo del conjunto de datos sera la de
#
# **Attrition**: La cual indica si un empleado renunció a la empresa (Yes) o permaneció (No).
#
# En este caso, la tarea principal sera asignar a cada empleado una etiqueta de “se queda” o “se va”, en función de sus características (edad, salario, años en la empresa, nivel de satisfacción laboral, entre otras).
#
# El objetivo no es calcular un valor exacto (como un salario o un número de años), lo cual correspondería a un problema de regresión, sino predecir a cuál de las dos categorías pertenece cada observación.

# %% [markdown]
# # **Segunda entrega**

# %% [markdown]
# ## 1 - Particion del dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

dataFrame = pd.read_csv("sample_data/test.csv", sep=",", encoding="latin1")
dataFrame = dataFrame.replace({r'[^\x00-\x7F]+': ''}, regex=True)

print("Shape:", dataFrame.shape)

target_col = 'Attrition'

X = dataFrame.drop(columns=[target_col])
y = dataFrame[target_col]

X = pd.get_dummies(X, drop_first=True)
X = X.astype("float32")
y = y.map({'Stayed': 0, 'Left': 1}).astype("float32")

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = X_scaled.astype("float32")

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y.values,
    test_size=0.2,
    random_state=42
)

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Shape: (14900, 24)
# Train shape: (11920, 42)
# Test shape: (2980, 42)

# %% [markdown]
# ## 2 - Entrenamiento y testeo de modelos

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### **Decision Tree**

# %%
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
tree_pred = tree.predict(X_test)
print("Decision Tree Accuracy:", accuracy_score(y_test, tree_pred))
# Out:
# Decision Tree Accuracy: 0.6523489932885906

# %% [markdown]
# ### **Random Forest**

# %%
forest = RandomForestClassifier()
forest.fit(X_train, y_train)
forest_pred = forest.predict(X_test)
print("Random Forest Accuracy:", accuracy_score(y_test, forest_pred))
# Out:
# Random Forest Accuracy: 0.7359060402684564

# %% [markdown]
# ### **Support vector machine**

# %%
svc = SVC()
svc.fit(X_train, y_train)
svc_pred = svc.predict(X_test)
print("SVC Accuracy:", accuracy_score(y_test, svc_pred))
# Out:
# SVC Accuracy: 0.7325503355704698

# %% [markdown]
# ## 3 - Curvas de aprendizaje

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### **Decision Tree con incrementos**

# %%
max_depths = range(1, 21)
dt_train_acc = []
dt_test_acc = []

for depth in max_depths:
    dt = DecisionTreeClassifier(max_depth=depth, random_state=42)
    dt.fit(X_train, y_train)
    dt_train_acc.append(accuracy_score(y_train, dt.predict(X_train)))
    dt_test_acc.append(accuracy_score(y_test, dt.predict(X_test)))

plt.figure(figsize=(8, 5))
plt.plot(max_depths, dt_train_acc, label='Train Accuracy', marker='o')
plt.plot(max_depths, dt_test_acc, label='Test Accuracy', marker='s')
plt.title("Decision Tree - Effect of max_depth")
plt.xlabel("max_depth")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Random Forest con n estimators**

# %%
n_estimators_list = [10, 50, 100, 200, 300]
rf_train_acc = []
rf_test_acc = []

for n in n_estimators_list:
    rf = RandomForestClassifier(n_estimators=n, random_state=42)
    rf.fit(X_train, y_train)
    rf_train_acc.append(accuracy_score(y_train, rf.predict(X_train)))
    rf_test_acc.append(accuracy_score(y_test, rf.predict(X_test)))

plt.figure(figsize=(8, 5))
plt.plot(n_estimators_list, rf_train_acc, label='Train Accuracy', marker='o')
plt.plot(n_estimators_list, rf_test_acc, label='Test Accuracy', marker='s')
plt.title("Random Forest - Effect of n_estimators")
plt.xlabel("n_estimators")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Support vector machine variando kernel**

# %%
kernels = ['linear', 'poly', 'rbf', 'sigmoid']
svc_train_acc = []
svc_test_acc = []

for k in kernels:
    svc = SVC(kernel=k)
    svc.fit(X_train_scaled, y_train)
    svc_train_acc.append(accuracy_score(y_train, svc.predict(X_train_scaled)))
    svc_test_acc.append(accuracy_score(y_test, svc.predict(X_test_scaled)))

plt.figure(figsize=(8, 5))
plt.bar(kernels, svc_test_acc, color='teal', alpha=0.7)
plt.title("SVC - Accuracy by Kernel Type")
plt.xlabel("Kernel")
plt.ylabel("Test Accuracy")
plt.show()

# %% [markdown]
# ## 4 - Cross Validation

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, mean_absolute_error

dataFrame = pd.read_csv("sample_data/test.csv", sep=",", encoding="latin1")
dataFrame = dataFrame.replace({r'[^\x00-\x7F]+': ''}, regex=True)

target_col = 'Attrition'
dataFrame = dataFrame.dropna(subset=[target_col])

X = dataFrame.drop(columns=[target_col])
y = dataFrame[target_col].map({'Stayed': 0, 'Left': 1})
X = pd.get_dummies(X, drop_first=True)

mask = ~y.isna()
X, y = X.loc[mask], y.loc[mask]

dt = DecisionTreeClassifier(max_depth=5, random_state=42)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

scores = cross_val_score(dt, X, y, cv=cv, scoring='accuracy')

print("=== CROSS VALIDATION RESULTS (DecisionTree, max_depth=5) ===")
print(f"Scores por fold: {scores}")
print(f"Mean accuracy: {scores.mean():.4f}")
print(f"Std accuracy:  {scores.std():.4f}")

y_pred = cross_val_predict(dt, X, y, cv=cv)

print("\n=== Classification Report ===")
print(classification_report(y, y_pred, target_names=['Stayed', 'Left']))

print("\n=== Confusion Matrix ===")
print(confusion_matrix(y, y_pred))

mae = mean_absolute_error(y, y_pred)
print(f"\nMean Absolute Error (treated as regression): {mae:.4f}")
# Out:
# === CROSS VALIDATION RESULTS (DecisionTree, max_depth=5) ===
# Scores por fold: [0.72248322 0.7114094  0.71308725 0.70671141 0.69865772]
# Mean accuracy: 0.7105
# Std accuracy:  0.0078
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#       Stayed       0.74      0.70      0.72      7868
#         Left       0.68      0.72      0.70      7032
#
#     accuracy                           0.71     14900
#    macro avg       0.71      0.71      0.71     14900
# weighted avg       0.71      0.71      0.71     14900
#
#
# === Confusion Matrix ===
# [[5512 2356]
#  [1958 5074]]
#
# Mean Absolute Error (treated as regression): 0.2895

# %% [markdown]
# # **Tercera Entrega**

# %% [markdown]
# ## 1 - DNN de 3 capas (128)

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Flatten( input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
model.compile(
    optimizer=tf.keras.optimizers.SGD(),
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=30)
loss, accuracy = model.evaluate(X_test, y_test)
print("Accuracy en test:", accuracy)
print("Loss en test:", loss)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_10 (Flatten)            │ (None, 42)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_40 (Dense)                │ (None, 128)            │         5,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 128)            │        16,512 │
# ...

# %% [markdown]
# ## 2 - Dnn de 3 capas (256)

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Flatten( input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(256, activation=tf.nn.relu),
    tf.keras.layers.Dense(256, activation=tf.nn.relu),
    tf.keras.layers.Dense(256, activation=tf.nn.relu),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
model.compile(
    optimizer=tf.keras.optimizers.SGD(),
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=30)
loss, accuracy = model.evaluate(X_test, y_test)
print("Accuracy en test:", accuracy)
print("Loss en test:", loss)
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_11 (Flatten)            │ (None, 42)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 256)            │        11,008 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_45 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_46 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_47 (Dense)                │ (None, 1)              │           257 │
# ...

# %% [markdown]
# ## 3 - DNN capa (64) capa (128) capa(256)

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Flatten( input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation=tf.nn.relu),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(256, activation=tf.nn.relu),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.summary()
model.compile(
    optimizer=tf.keras.optimizers.SGD(),
    loss='binary_crossentropy',
    metrics=['accuracy']
)
model.fit(X_train, y_train, epochs=30)
loss, accuracy = model.evaluate(X_test, y_test)
print("Accuracy en test:", accuracy)
print("Loss en test:", loss)
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_12 (Flatten)            │ (None, 42)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_48 (Dense)                │ (None, 64)             │         2,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_49 (Dense)                │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_50 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 1)              │           257 │
# ...
